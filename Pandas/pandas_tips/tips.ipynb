# %%
import pandas as pd 
pd.__version__
# Out:
# '1.3.4'

# %%
# Make a DataFrame 
data = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# %%
data
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
import numpy as np

# %%
# DataFrame using np.array
data = pd.DataFrame(np.random.randn(3, 4), columns=['A', 'B', 'C', 'D'])

# %%
data
# Out:
#           A         B         C         D
# 0  1.634298  0.044707  1.812542 -2.400218
# 1  0.811860 -1.001781 -0.494219  1.010921
# 2  0.008977  0.091809 -0.753666  1.034256

# %%
data.rename(columns={'A': 'a', 'B': 'b', 'C': 'c', 'D': 'd'}, inplace=True)

# %%
data
# Out:
#           a         b         c         d
# 0  1.634298  0.044707  1.812542 -2.400218
# 1  0.811860 -1.001781 -0.494219  1.010921
# 2  0.008977  0.091809 -0.753666  1.034256

# %%
data.columns = ("a_a", "b_b", "c_c", "d_d")

# %%
data
# Out:
#         a_a       b_b       c_c       d_d
# 0  1.634298  0.044707  1.812542 -2.400218
# 1  0.811860 -1.001781 -0.494219  1.010921
# 2  0.008977  0.091809 -0.753666  1.034256

# %%
data.columns=data.columns.str.replace('_', '')

# %%
data
# Out:
#          aa        bb        cc        dd
# 0  1.634298  0.044707  1.812542 -2.400218
# 1  0.811860 -1.001781 -0.494219  1.010921
# 2  0.008977  0.091809 -0.753666  1.034256

# %%
# Adding prefix to columns
data.add_prefix('pre_')
# Out:
#      pre_aa    pre_bb    pre_cc    pre_dd
# 0  1.634298  0.044707  1.812542 -2.400218
# 1  0.811860 -1.001781 -0.494219  1.010921
# 2  0.008977  0.091809 -0.753666  1.034256

# %%
data
# Out:
#          aa        bb        cc        dd
# 0  1.634298  0.044707  1.812542 -2.400218
# 1  0.811860 -1.001781 -0.494219  1.010921
# 2  0.008977  0.091809 -0.753666  1.034256

# %%
data.columns = ("a_a", "b_b", "c_c", "d_d")

# %%
data
# Out:
#         a_a       b_b       c_c       d_d
# 0  1.634298  0.044707  1.812542 -2.400218
# 1  0.811860 -1.001781 -0.494219  1.010921
# 2  0.008977  0.091809 -0.753666  1.034256

# %%
# Using template data
import pandas as pd
import numpy as np
import seaborn as sns   # For plotting
import matplotlib.pyplot as plt
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Summary of data
titanic.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
# Columns names
titanic.columns
# Out:
# Index(['Unnamed: 0', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# Saving data to csv
titanic.to_csv("titanic.csv")
iris.to_csv("iris.csv")

# %%
# !pip install openpyxl

# %%
# Saving data to excel
titanic.to_excel("titanic.xlsx")

# %%
# Saving data to numpy file
titanic.to_csv("titanic.npy")

# %%
# Using our own data
data = pd.read_csv("titanic.csv")
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  survived  pclass     sex   age  sibsp  parch  \
# 0           0             0         0       3    male  22.0      1      0
# 1           1             1         1       1  female  38.0      1      0
# 2           2             2         1       3  female  26.0      0      0
# 3           3             3         1       1  female  35.0      1      0
# 4           4             4         0       3    male  35.0      0      0
#
#       fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1  71.2833        C  First  woman       False    C    Cherbourg   yes  False
# 2   7.9250        S  Third  woman       False  NaN  Southampton   yes   True
# 3  53.1000        S  First  woman       False    C  Southampton   yes  False
# 4   8.0500        S  Third    man        True  NaN  Southampton    no   True

# %%
# Reverse row order
data.iloc[::-1]
# Out:
#      Unnamed: 0  Unnamed: 0.1  survived  pclass     sex   age  sibsp  parch  \
# 890         890           890         0       3    male  32.0      0      0
# 889         889           889         1       1    male  26.0      0      0
# 888         888           888         0       3  female   NaN      1      2
# 887         887           887         1       1  female  19.0      0      0
# 886         886           886         0       2    male  27.0      0      0
# ..          ...           ...       ...     ...     ...   ...    ...    ...
# 4             4             4         0       3    male  35.0      0      0
# 3             3             3         1       1  female  35.0      1      0
# 2             2             2         1       3  female  26.0      0      0
# 1             1             1         1       1  female  38.0      1      0
# 0             0             0         0       3    male  22.0      1      0
#
# ...

# %%
# reset index
data.reset_index(drop=True)
# Out:
#      Unnamed: 0  Unnamed: 0.1  survived  pclass     sex   age  sibsp  parch  \
# 0             0             0         0       3    male  22.0      1      0
# 1             1             1         1       1  female  38.0      1      0
# 2             2             2         1       3  female  26.0      0      0
# 3             3             3         1       1  female  35.0      1      0
# 4             4             4         0       3    male  35.0      0      0
# ..          ...           ...       ...     ...     ...   ...    ...    ...
# 886         886           886         0       2    male  27.0      0      0
# 887         887           887         1       1  female  19.0      0      0
# 888         888           888         0       3  female   NaN      1      2
# 889         889           889         1       1    male  26.0      0      0
# 890         890           890         0       3    male  32.0      0      0
#
# ...

# %%
# Reverse column order
data.iloc[:, ::-1]
# Out:
#      alone alive  embark_town deck  adult_male    who   class embarked  \
# 0    False    no  Southampton  NaN        True    man   Third        S
# 1    False   yes    Cherbourg    C       False  woman   First        C
# 2     True   yes  Southampton  NaN       False  woman   Third        S
# 3    False   yes  Southampton    C       False  woman   First        S
# 4     True    no  Southampton  NaN        True    man   Third        S
# ..     ...   ...          ...  ...         ...    ...     ...      ...
# 886   True    no  Southampton  NaN        True    man  Second        S
# 887   True   yes  Southampton    B       False  woman   First        S
# 888  False    no  Southampton  NaN       False  woman   Third        S
# 889   True   yes    Cherbourg    C        True    man   First        C
# 890   True    no   Queenstown  NaN        True    man   Third        Q
#
#         fare  parch  sibsp   age     sex  pclass  survived  Unnamed: 0.1  \
# ...

# %%
# select number in data frame
data.select_dtypes(include=['number'])
# Out:
#      Unnamed: 0  Unnamed: 0.1  survived  pclass   age  sibsp  parch     fare
# 0             0             0         0       3  22.0      1      0   7.2500
# 1             1             1         1       1  38.0      1      0  71.2833
# 2             2             2         1       3  26.0      0      0   7.9250
# 3             3             3         1       1  35.0      1      0  53.1000
# 4             4             4         0       3  35.0      0      0   8.0500
# ..          ...           ...       ...     ...   ...    ...    ...      ...
# 886         886           886         0       2  27.0      0      0  13.0000
# 887         887           887         1       1  19.0      0      0  30.0000
# 888         888           888         0       3   NaN      1      2  23.4500
# 889         889           889         1       1  26.0      0      0  30.0000
# 890         890           890         0       3  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %%
# select object in data frame
data.select_dtypes(include=['object'])
# Out:
#         sex embarked   class    who deck  embark_town alive
# 0      male        S   Third    man  NaN  Southampton    no
# 1    female        C   First  woman    C    Cherbourg   yes
# 2    female        S   Third  woman  NaN  Southampton   yes
# 3    female        S   First  woman    C  Southampton   yes
# 4      male        S   Third    man  NaN  Southampton    no
# ..      ...      ...     ...    ...  ...          ...   ...
# 886    male        S  Second    man  NaN  Southampton    no
# 887  female        S   First  woman    B  Southampton   yes
# 888  female        S   Third  woman  NaN  Southampton    no
# 889    male        C   First    man    C    Cherbourg   yes
# 890    male        Q   Third    man  NaN   Queenstown    no
#
# [891 rows x 7 columns]

# %%
data.select_dtypes(include=['number', 'object'])
# Out:
#      Unnamed: 0  Unnamed: 0.1  survived  pclass     sex   age  sibsp  parch  \
# 0             0             0         0       3    male  22.0      1      0
# 1             1             1         1       1  female  38.0      1      0
# 2             2             2         1       3  female  26.0      0      0
# 3             3             3         1       1  female  35.0      1      0
# 4             4             4         0       3    male  35.0      0      0
# ..          ...           ...       ...     ...     ...   ...    ...    ...
# 886         886           886         0       2    male  27.0      0      0
# 887         887           887         1       1  female  19.0      0      0
# 888         888           888         0       3  female   NaN      1      2
# 889         889           889         1       1    male  26.0      0      0
# 890         890           890         0       3    male  32.0      0      0
#
# ...

# %%
# exclude number in data frame
data.select_dtypes(exclude=['number'])
# Out:
#         sex embarked   class    who  adult_male deck  embark_town alive  alone
# 0      male        S   Third    man        True  NaN  Southampton    no  False
# 1    female        C   First  woman       False    C    Cherbourg   yes  False
# 2    female        S   Third  woman       False  NaN  Southampton   yes   True
# 3    female        S   First  woman       False    C  Southampton   yes  False
# 4      male        S   Third    man        True  NaN  Southampton    no   True
# ..      ...      ...     ...    ...         ...  ...          ...   ...    ...
# 886    male        S  Second    man        True  NaN  Southampton    no   True
# 887  female        S   First  woman       False    B  Southampton   yes   True
# 888  female        S   Third  woman       False  NaN  Southampton    no  False
# 889    male        C   First    man        True    C    Cherbourg   yes   True
# 890    male        Q   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 9 columns]

# %%
#type casting
df = data.astype(str)

# %%
df.dtypes
# Out:
# Unnamed: 0      object
# Unnamed: 0.1    object
# survived        object
# pclass          object
# sex             object
# age             object
# sibsp           object
# parch           object
# fare            object
# embarked        object
# class           object
# who             object
# adult_male      object
# deck            object
# embark_town     object
# alive           object
# alone           object
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# Unnamed: 0      True
# Unnamed: 0.1    True
# survived        True
# pclass          True
# sex             True
# age             True
# sibsp           True
# parch           True
# fare            True
# embarked        True
# class           True
# who             True
# adult_male      True
# deck            True
# embark_town     True
# alive           True
# alone           True
# dtype: bool

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# %%
df.astype({'A': 'int64', 'B': 'float64'}).dtypes
# Out:
# A      int64
# B    float64
# dtype: object

# %%
pd.to_numeric(df['B'], errors='coerce').dtypes
# Out:
# dtype('int64')

# %%
# Reduce dataframe size
data.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  survived  pclass     sex   age  sibsp  parch  \
# 0           0             0         0       3    male  22.0      1      0
# 1           1             1         1       1  female  38.0      1      0
#
#       fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1  71.2833        C  First  woman       False    C    Cherbourg   yes  False

# %%
ns = sns.load_dataset("titanic")
ns.shape
# Out:
# (891, 16)

# %%
ns.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    category
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    category
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(5), object(5)
# memory usage: 320.7 KB

# %%
ns.sample(frac=0.5).shape
# Out:
# (446, 16)

# %%
# copy data from clipboard
# data set download 
data = pd.read_csv("titanic.csv")
data.to_excel("kashti.xlsx")

# %%
# read clipboard data
data = pd.read_clipboard()
data
# Out:
# Empty DataFrame
# Columns: [download]
# Index: []

# %%
a,b,c = map(int,input().split())

count = 0 
for i in range(a,b+1):
    if c%i ==0:
        count = count + 1
print(count)
# Out:
# 3

# %%
def solution(n, a):
    b= a
    b[0] = 0 + a[0] + a[1]
    for i in range(n-2):
        b[i]=a[i] + a[i+1] + a[i+2]

# %%
def solution(n, a):
    b = a 
    b[0] = 0 + a[0] + a[1]
    for i in range(n):
        for j in range(i-1):
            b[j] = a[j] + a[j+1] + a[j+2]

# %%
n = 5 
a = [4, 0, 1, -2, 3]
solution (n, a)

# %%
b
# Out:
# [6, -2, 2, -2, 3]

# %%
b =a

# %%
b
# Out:
# [4, 0, 1, -2, 3]

# %%
a,b = map(int,input().split())
d = a//b
r = a%b
g = a/b
print(d,r,f'{g:.10f}')
# Out:
# 1 1 1.5000000000

# %%
from math import pi
a = float(input())
area = pi * a**2
cir = 2 * pi * a
print("%.6f"%area, "%.6f"%cir)
# Out:
# 12.566371 12.566371

# %%
while True:
    t = input().split()
    a = int(t[0])
    op = t[1]
    b = int(t[2])
    if op == '?':
        break
    if op == '+':
        print("%d"%(a+b))
    elif op == '-':
        print("%d"%(a-b))
    elif op == '/':
        print("%d"%(a/b))
    else:
        print("%d"%(a*b))
# Out:
# 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17444/4158408465.py in <module>
#       1 while True:
#       2     t = input().split()
# ----> 3     a = int(t[0])
#       4     op = t[1]
#       5     b = int(t[2])
#
# ValueError: invalid literal for int() with base 10: '#'

# %%
#split data frame into two subsets
import pandas as pd
data = pd.read_csv("titanic.csv")
data.head()
len(data)
# Out:
# 891

# %%
ks = data.sample(frac=0.5, random_state=1)

# %%
ks.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1  survived  pclass     sex   age  sibsp  parch  \
# 862         862           862         1       1  female  48.0      0      0
# 223         223           223         0       3    male   NaN      0      0
# 84           84            84         1       2  female  17.0      0      0
# 680         680           680         0       3  female   NaN      0      0
# 535         535           535         1       2  female   7.0      0      2
#
#         fare embarked   class    who  adult_male deck  embark_town alive  \
# 862  25.9292        S   First  woman       False    D  Southampton   yes
# 223   7.8958        S   Third    man        True  NaN  Southampton    no
# 84   10.5000        S  Second  woman       False  NaN  Southampton   yes
# 680   8.1375        Q   Third  woman       False  NaN   Queenstown    no
# 535  26.2500        S  Second  child       False  NaN  Southampton   yes
#
#      alone
# 862   True
# 223   True
# 84    True
# 680   True
# ...

# %%
len(ks)
# Out:
# 446

# %%
n = int(input())
a = list(map(int, input().split()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14996/3327491977.py in <module>
# ----> 1 n = int(input())
#       2 a = list(map(int, input().split()))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a
# Out:
# [12, 23, 34, 15, 15]

# %%
min = a[0]
max = a[0]
sum = 0

# %%
# Out:
# 34 12 99

# %%
# Filtering a dataset 
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  survived  pclass     sex   age  sibsp  parch  \
# 0           0             0         0       3    male  22.0      1      0
# 1           1             1         1       1  female  38.0      1      0
# 2           2             2         1       3  female  26.0      0      0
# 3           3             3         1       1  female  35.0      1      0
# 4           4             4         0       3    male  35.0      0      0
#
#       fare embarked  class    who  adult_male deck  embark_town alive  alone
# 0   7.2500        S  Third    man        True  NaN  Southampton    no  False
# 1  71.2833        C  First  woman       False    C    Cherbourg   yes  False
# 2   7.9250        S  Third  woman       False  NaN  Southampton   yes   True
# 3  53.1000        S  First  woman       False    C  Southampton   yes  False
# 4   8.0500        S  Third    man        True  NaN  Southampton    no   True

# %%
data.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data[data.sex == 'female']
# Out:
#      Unnamed: 0  Unnamed: 0.1  survived  pclass     sex   age  sibsp  parch  \
# 1             1             1         1       1  female  38.0      1      0
# 2             2             2         1       3  female  26.0      0      0
# 3             3             3         1       1  female  35.0      1      0
# 8             8             8         1       3  female  27.0      0      2
# 9             9             9         1       2  female  14.0      1      0
# ..          ...           ...       ...     ...     ...   ...    ...    ...
# 880         880           880         1       2  female  25.0      0      1
# 882         882           882         0       3  female  22.0      0      0
# 885         885           885         0       3  female  39.0      0      5
# 887         887           887         1       1  female  19.0      0      0
# 888         888           888         0       3  female   NaN      1      2
#
# ...

# %%
data.pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
# Filtering by large catergories
data.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
(data.age > 50).value_counts()
# Out:
# False    827
# True      64
# Name: age, dtype: int64

# %%
data.age.value_counts().nlargest(3)
# Out:
# 24.0    30
# 22.0    27
# 18.0    26
# Name: age, dtype: int64

# %%
data['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64
